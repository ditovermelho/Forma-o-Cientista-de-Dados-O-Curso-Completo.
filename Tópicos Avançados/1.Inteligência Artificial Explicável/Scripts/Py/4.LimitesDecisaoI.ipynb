# %% [markdown]
# # Formação Cientista de Dados II  - Limites de Decisão
# ## Prof. Fernando Amaral

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (1.12.0)
# Requirement already satisfied: numpy>=1.16.2 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (1.4.1.post1)
# Requirement already satisfied: matplotlib>=3.0.0 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (3.8.3)
# Requirement already satisfied: joblib>=0.13.2 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=8 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.3.0)
# Requirement already satisfied: six>=1.5 in d:\documents\forma-o-cientista-de-dados-o-curso-completo\tópicos avançados\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.4 MB 2.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model  
from mlxtend.plotting import plot_decision_regions
import pandas as pd

# %%
modelo =  linear_model.LinearRegression()
carros = pd.read_csv('../../Dados/carros.csv', sep=";")
carros
# Out:
#     Consumo  Cilindros  Cilindradas  RelEixoTraseiro  Peso  Tempo  TipoMotor  \
# 0        21          6          160               39   262   1646          0
# 1        21          6          160               39  2875   1702          0
# 2       228          4          108              385   232   1861          1
# 3       214          6          258              308  3215   1944          1
# 4       187          8          360              315   344   1702          0
# 5       181          6          225              276   346   2022          1
# 6       143          8          360              321   357   1584          0
# 7       244          4         1467              369   319     20          1
# 8       228          4         1408              392   315    229          1
# 9       192          6         1676              392   344    183          1
# 10      178          6         1676              392   344    189          1
# 11      164          8         2758              307   407    174          0
# 12      173          8         2758              307   373    176          0
# 13      152          8         2758              307   378     18          0
# 14      104          8          472              293   525   1798          0
# 15      104          8          460                3  5424   1782          0
# 16      147          8          440              323  5345   1742          0
# 17      324          4          787              408    22   1947          1
# 18      304          4          757              493  1615   1852          1
# 19      339          4          711              422  1835    199          1
# 20      215          4         1201               37  2465   2001          1
# 21      155          8          318              276   352   1687          0
# 22      152          8          304              315  3435    173          0
# 23      133          8          350              373   384   1541          0
# 24      192          8          400              308  3845   1705          0
# 25      273          4           79              408  1935    189          1
# 26       26          4         1203              443   214    167          0
# 27      304          4          951              377  1513    169          1
# 28      158          8          351              422   317    145          0
# 29      197          6          145              362   277    155          0
# 30       15          8          301              354   357    146          0
# 31      214          4          121              411   278    186          1
#
#     Transmissao  Marchas  Carburadors   HP
# 0             1        4            4  110
# 1             1        4            4  110
# 2             1        4            1   93
# 3             0        3            1  110
# 4             0        3            2  175
# 5             0        3            1  105
# 6             0        3            4  245
# 7             0        4            2   62
# 8             0        4            2   95
# 9             0        4            4  123
# 10            0        4            4  123
# 11            0        3            3  180
# 12            0        3            3  180
# 13            0        3            3  180
# 14            0        3            4  205
# 15            0        3            4  215
# 16            0        3            4  230
# 17            1        4            1   66
# 18            1        4            2   52
# 19            1        4            1   65
# 20            0        3            1   97
# 21            0        3            2  150
# 22            0        3            2  150
# 23            0        3            4  245
# 24            0        3            2  175
# 25            1        4            1   66
# 26            1        5            2   91
# 27            1        5            2  113
# 28            1        5            4  264
# 29            1        5            6  175
# 30            1        5            8  335
# 31            1        4            2  109

# %%
#converter para numpy
carros = carros.to_numpy()

# %%
#prevendo o número de carburadores
y = carros[:,9]
#consumo e cilindoros
X = carros[:, 0:2]
X
# Out:
# array([[ 21,   6],
#        [ 21,   6],
#        [228,   4],
#        [214,   6],
#        [187,   8],
#        [181,   6],
#        [143,   8],
#        [244,   4],
#        [228,   4],
#        [192,   6],
#        [178,   6],
#        [164,   8],
#        [173,   8],
#        [152,   8],
#        [104,   8],
#        [104,   8],
#        [147,   8],
#        [324,   4],
#        [304,   4],
#        [339,   4],
#        [215,   4],
#        [155,   8],
#        [152,   8],
#        [133,   8],
#        [192,   8],
#        [273,   4],
#        [ 26,   4],
#        [304,   4],
#        [158,   8],
#        [197,   6],
#        [ 15,   8],
#        [214,   4]], dtype=int64)

# %%
y
# Out:
# array([4, 4, 1, 1, 2, 1, 4, 2, 2, 4, 4, 3, 3, 3, 4, 4, 4, 1, 2, 1, 1, 2,
#        2, 4, 2, 1, 2, 2, 4, 6, 8, 2], dtype=int64)

# %%
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
fig = plot_decision_regions(X=X, y=y,clf=modelo)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", ncol=2)
plt.title('Limites de Decisão')
plt.xlabel('Consumo')
plt.ylabel('Cilindros')
plt.show()
# Out:
# d:\Documents\Forma-o-Cientista-de-Dados-O-Curso-Completo\Tópicos Avançados\venv\Lib\site-packages\mlxtend\plotting\decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
