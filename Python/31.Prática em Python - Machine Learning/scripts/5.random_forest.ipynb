# %% [markdown]
# # Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# # Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('../dados/Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1508661767),
#  DecisionTreeClassifier(max_features='sqrt', random_state=411922015),
#  DecisionTreeClassifier(max_features='sqrt', random_state=591428607),
#  DecisionTreeClassifier(max_features='sqrt', random_state=84522103),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1958658826),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1372899029),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1601778533),
#  DecisionTreeClassifier(max_features='sqrt', random_state=568611761),
#  DecisionTreeClassifier(max_features='sqrt', random_state=245335913),
#  DecisionTreeClassifier(max_features='sqrt', random_state=806195948),
#  DecisionTreeClassifier(max_features='sqrt', random_state=505793098),
#  DecisionTreeClassifier(max_features='sqrt', random_state=256735605),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1378527556),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1660781202),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1284726119),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1697771905),
#  DecisionTreeClassifier(max_features='sqrt', random_state=138811039),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1005387380),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1524607477),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1046193701),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2068759350),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1887228579),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1211287040),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1220313821),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2042000474),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1401874774),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1425846393),
#  DecisionTreeClassifier(max_features='sqrt', random_state=99852300),
#  DecisionTreeClassifier(max_features='sqrt', random_state=935059024),
#  DecisionTreeClassifier(max_features='sqrt', random_state=683166191),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1589457607),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1344094424),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2051700333),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1787458151),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1836183472),
#  DecisionTreeClassifier(max_features='sqrt', random_state=165813748),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1915978888),
#  DecisionTreeClassifier(max_features='sqrt', random_state=596613789),
#  DecisionTreeClassifier(max_features='sqrt', random_state=920913714),
#  DecisionTreeClassifier(max_features='sqrt', random_state=644205587),
#  DecisionTreeClassifier(max_features='sqrt', random_state=743094161),
#  DecisionTreeClassifier(max_features='sqrt', random_state=133369039),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2060393594),
#  DecisionTreeClassifier(max_features='sqrt', random_state=820310613),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1537916499),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1179079325),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1084598327),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1342175324),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1534165792),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1243014998),
#  DecisionTreeClassifier(max_features='sqrt', random_state=327715173),
#  DecisionTreeClassifier(max_features='sqrt', random_state=845376565),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1997574621),
#  DecisionTreeClassifier(max_features='sqrt', random_state=150097509),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1780501948),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1494707798),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2125297118),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2079504943),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1254769346),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1836391802),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1884999275),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2068514361),
#  DecisionTreeClassifier(max_features='sqrt', random_state=536696609),
#  DecisionTreeClassifier(max_features='sqrt', random_state=122865427),
#  DecisionTreeClassifier(max_features='sqrt', random_state=812524158),
#  DecisionTreeClassifier(max_features='sqrt', random_state=324489877),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2143739367),
#  DecisionTreeClassifier(max_features='sqrt', random_state=804863702),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1236875142),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2056534979),
#  DecisionTreeClassifier(max_features='sqrt', random_state=293814712),
#  DecisionTreeClassifier(max_features='sqrt', random_state=694105130),
#  DecisionTreeClassifier(max_features='sqrt', random_state=369083908),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1205842104),
#  DecisionTreeClassifier(max_features='sqrt', random_state=497269142),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1453091772),
#  DecisionTreeClassifier(max_features='sqrt', random_state=877163730),
#  DecisionTreeClassifier(max_features='sqrt', random_state=63962442),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1413653172),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1814145895),
#  DecisionTreeClassifier(max_features='sqrt', random_state=671835089),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1277488088),
#  DecisionTreeClassifier(max_features='sqrt', random_state=130240188),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1598160476),
#  DecisionTreeClassifier(max_features='sqrt', random_state=771302425),
#  DecisionTreeClassifier(max_features='sqrt', random_state=701458690),
#  DecisionTreeClassifier(max_features='sqrt', random_state=157138589),
#  DecisionTreeClassifier(max_features='sqrt', random_state=434693630),
#  DecisionTreeClassifier(max_features='sqrt', random_state=351789767),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1813342973),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1839146322),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1065204588),
#  DecisionTreeClassifier(max_features='sqrt', random_state=676333903),
#  DecisionTreeClassifier(max_features='sqrt', random_state=120045393),
#  DecisionTreeClassifier(max_features='sqrt', random_state=93541001),
#  DecisionTreeClassifier(max_features='sqrt', random_state=899340866),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1624185447),
#  DecisionTreeClassifier(max_features='sqrt', random_state=552329706),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1218952052),
#  DecisionTreeClassifier(max_features='sqrt', random_state=353013107)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7733333333333333
